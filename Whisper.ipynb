# %%
# !pip install -U openai-whisper

# %%
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 20 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !whisper "/content/gdrive/MyDrive/Colab Notebooks/data.mp3" --model medium
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:13.000]  I can say we are at the moment in advance stage, I can say, because we've been adopting different automations.
# [00:13.000 --> 00:20.000]  I have a different view from the previous panelists when we discussed about the book.
# [00:20.000 --> 00:27.000]  I remember there's one of the panelists saying that automation is the same with integration.
# [00:27.000 --> 00:30.000]  For me, I see that it's a different part.
# [00:30.000 --> 00:37.000]  We can, I see automation can be done in a cluster way, which that's what we did.
# [00:37.000 --> 00:41.000]  For instance, like when we are talking about a procurement process.
# [00:41.000 --> 00:49.000]  Today, we are using Coupa as one of automations around the procurement world.
# [00:50.000 --> 00:55.000]  We cover from the source to pay process, meaning not only procurement,
# ...
